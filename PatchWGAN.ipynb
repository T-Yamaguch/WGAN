# %% [markdown]
# <a href="https://colab.research.google.com/github/T-Yamaguch/WGAN/blob/master/PatchWGAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import tensorflow as tf
from tensorflow.keras import Model
from tensorflow.keras.layers import Input, Concatenate, Conv2D, \
MaxPooling2D, Activation, ReLU, LeakyReLU, UpSampling2D, BatchNormalization, \
Dropout, Dense, Flatten, Add, LayerNormalization, GaussianNoise, Reshape, Lambda
from keras.regularizers import l2

class conv_block(Model):
  def __init__(self, filter_num, kernel_size, kernel_regularizer= l2(0.001)):
    super(conv_block, self).__init__()
    self.conv = Conv2D(filter_num, kernel_size, padding = 'same', kernel_regularizer= kernel_regularizer)
    self.norm = BatchNormalization(trainable=True)
    self.act = LeakyReLU()
    self.up = UpSampling2D((2,2))
    self.noise = GaussianNoise(0.2)

  def call(self, x):
    x = self.conv(x)
    x = self.norm(x)
    x = self.act(x)
    x = self.up(x)
    x = self.noise(x)
    return x

class res_block(Model):
  def __init__(self, filter_num, kernel_size, kernel_regularizer= l2(0.001)):
    super(res_block, self).__init__()
    self.conv1 = Conv2D(filter_num, kernel_size, padding = 'same', kernel_regularizer= kernel_regularizer)
    self.conv2 = Conv2D(filter_num, kernel_size, padding = 'same', kernel_regularizer= kernel_regularizer)
    self.norm1 = BatchNormalization(trainable=True)
    self.norm2 = BatchNormalization(trainable=True)
    self.act1 = LeakyReLU()
    self.act2 = LeakyReLU()
    self.add = Add()

  def call(self, x):
    y = self.conv1(x)
    y = self.norm1(y)
    y = self.act1(y)
    y = self.conv2(y)
    y = self.norm2(y)
    y = self.act2(y)
    x = self.add([x, y])
    return x

class disc_block(Model):
  def __init__(self, filter_num, kernel_size, kernel_regularizer= l2(0.001)):
    super(disc_block, self).__init__()
    self.conv = Conv2D(filter_num, kernel_size, padding = 'same', kernel_regularizer= kernel_regularizer)
    self.norm = BatchNormalization(trainable=True)
    self.act = LeakyReLU()
    self.pooling = MaxPooling2D((2,2), strides=(2,2))
    self.drop = Dropout(0.3)

  def call(self, x):
    x = self.conv(x)
    # x = self.norm(x) dにnorm入れないほうがいいという噂
    x = self.act(x)
    x = self.pooling(x)
    x = self.drop(x)
    return x

class dense_block(Model):
  def __init__(self, filter_num, kernel_regularizer= l2(0.001)):
    super(dense_block, self).__init__()
    self.dense = Dense(filter_num, kernel_regularizer= kernel_regularizer)
    self.norm = BatchNormalization(trainable=True)
    self.act = LeakyReLU()

  def call(self, x):
    x = self.dense(x)
    x = self.norm(x)
    x = self.act(x)
    return x

class dense_block_wo_norm(Model):
  def __init__(self, filter_num, kernel_regularizer= l2(0.001)):
    super(dense_block_wo_norm, self).__init__()
    self.dense = Dense(filter_num, kernel_regularizer= kernel_regularizer)
    self.act = LeakyReLU()

  def call(self, x):
    x = self.dense(x)
    x = self.act(x)
    return x

# %%
class Generator():
  def __init__(self):
    self.channel_num = 256
    self.layer_num = 3
    self.res_num = 0
    self.latent_num = 8
    self.inputs = Input(shape=(self.latent_num)) 
    self.kernel_size = (5, 5)
    self.name = 'generator'
    self.kernel_regularizer= None
      
  def model(self):
    x = self.inputs

    final_size = 4*4*self.channel_num
    data_size = self.latent_num

    while data_size*64 < final_size:
      data_size *= 64
      x = dense_block(data_size, kernel_regularizer= self.kernel_regularizer)(x)

    x = dense_block(final_size, kernel_regularizer= self.kernel_regularizer)(x)
    x = Reshape((4, 4, self.channel_num))(x)

    filter_num = self.channel_num
    
    for n in range(self.layer_num):
      for m in range(self.res_num):
        x = res_block(filter_num, self.kernel_size, kernel_regularizer= self.kernel_regularizer)(x)
      # filter_num /= 2
      x = conv_block(filter_num, self.kernel_size, kernel_regularizer= self.kernel_regularizer)(x)

    for m in range(self.res_num):
      x = res_block(filter_num, self.kernel_size, kernel_regularizer= self.kernel_regularizer)(x)

    x = Conv2D(3, self.kernel_size, padding = 'same', kernel_regularizer= self.kernel_regularizer)(x)
    x = Activation('sigmoid')(x)
    outputs = x
    return Model(inputs = self.inputs, outputs = outputs, name = self.name)

g = Generator()
g.model().summary()
# Out:
# Model: "generator"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 8)]               0
# _________________________________________________________________
# dense_block (dense_block)    (None, 512)               6656
# _________________________________________________________________
# dense_block_1 (dense_block)  (None, 4096)              2117632
# _________________________________________________________________
# reshape (Reshape)            (None, 4, 4, 256)         0
# _________________________________________________________________
# conv_block (conv_block)      (None, 8, 8, 256)         1639680
# _________________________________________________________________
# conv_block_1 (conv_block)    (None, 16, 16, 256)       1639680
# _________________________________________________________________
# conv_block_2 (conv_block)    (None, 32, 32, 256)       1639680
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 3)         19203
# _________________________________________________________________
# activation (Activation)      (None, 32, 32, 3)         0
# =================================================================
# Total params: 7,062,531
# Trainable params: 7,051,779
# Non-trainable params: 10,752
# _________________________________________________________________

# %%
class Discriminator():
  def __init__(self):
    self.channel_num = 128
    self.layer_num = 2
    self.latent_num = 8
    self.input_shape = (32, 32, 3)
    self.patch_shape = (16, 16, 3)
    self.patch_stride = 8
    self.inputs = Input(shape=self.input_shape)
    self.patch_inputs = Input(shape=self.patch_shape)
    self.kernel_size = (5, 5)
    self.name = 'discriminator'
    self.kernel_regularizer= None

  def patch_model(self):
    x = self.patch_inputs

    filter_num = self.channel_num
    for n in range(self.layer_num):
      x = disc_block(filter_num, self.kernel_size, kernel_regularizer= self.kernel_regularizer)(x)
      filter_num *= 2

    x = Flatten()(x)
    x = dense_block_wo_norm(64, kernel_regularizer= self.kernel_regularizer)(x)
    x = Dense(1)(x)

    outputs = x

    return Model(inputs = self.patch_inputs, outputs = outputs, name = 'patch_model')

  def model(self):
    x = self.inputs

    h, w = self.input_shape[:-1]
    ph, pw = self.patch_shape[:-1]
    st = self.patch_stride
    list_row_idx = [(i*st, i*st+ph) for i in range((h-ph)//st+1)]
    list_col_idx = [(i*st, i*st+pw) for i in range((w-pw)//st+1)]

    list_patch = []
    for row_idx in list_row_idx:
        for col_idx in list_col_idx:
            x_patch = Lambda(lambda z: z[:, row_idx[0]:row_idx[1], col_idx[0]:col_idx[1], :])(x)
            list_patch.append(x_patch)

    patch_num = ((h-ph)//st+1)*((w-pw)//st+1)

    patch_model = self.patch_model()
    x = [patch_model(list_patch[i]) for i in range(patch_num)]

    x = Concatenate(axis=-1)(x)


    # filter_num = self.channel_num
    # for n in range(self.layer_num):
    #   x = disc_block(filter_num, self.kernel_size, kernel_regularizer= self.kernel_regularizer)(x)
    #   filter_num *= 2
    # x = Conv2D(filter_num, self.kernel_size, padding = 'same', kernel_regularizer= self.kernel_regularizer)(x)
    # x = LeakyReLU()(x)

    # x1 = Dense(1)(x)
    # x1 = Activation('tanh')(x1)

    # x2 = Dense(self.latent_num)(x)
    # x2 = Activation('sigmoid')(x2)

    # outputs = [x1, x2]

    # x = Flatten()(x)
    # x = dense_block_wo_norm(64, kernel_regularizer= self.kernel_regularizer)(x)
    outputs = Dense(1)(x)

    return Model(inputs = self.inputs, outputs = outputs, name = self.name)

d = Discriminator()
d.patch_model().summary()
d.model().summary()
# Out:
# Model: "patch_model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 16, 16, 3)]       0
# _________________________________________________________________
# disc_block (disc_block)      (None, 8, 8, 128)         9728
# _________________________________________________________________
# disc_block_1 (disc_block)    (None, 4, 4, 256)         819456
# _________________________________________________________________
# flatten (Flatten)            (None, 4096)              0
# _________________________________________________________________
# dense_block_wo_norm (dense_b (None, 64)                262208
# _________________________________________________________________
# dense_block_wo_norm_1 (dense (None, 1)                 65
# =================================================================
# Total params: 1,091,457
# Trainable params: 1,091,457
# Non-trainable params: 0
# _________________________________________________________________
# Model: "discriminator"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 16, 16, 3)    0           input_2[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 16, 16, 3)    0           input_2[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 16, 16, 3)    0           input_2[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 16, 16, 3)    0           input_2[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 16, 16, 3)    0           input_2[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 16, 16, 3)    0           input_2[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 16, 16, 3)    0           input_2[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 16, 16, 3)    0           input_2[0][0]
# __________________________________________________________________________________________________
# lambda_8 (Lambda)               (None, 16, 16, 3)    0           input_2[0][0]
# __________________________________________________________________________________________________
# patch_model (Functional)        (None, 1)            1091457     lambda[0][0]
#                                                                  lambda_1[0][0]
#                                                                  lambda_2[0][0]
#                                                                  lambda_3[0][0]
#                                                                  lambda_4[0][0]
#                                                                  lambda_5[0][0]
#                                                                  lambda_6[0][0]
#                                                                  lambda_7[0][0]
#                                                                  lambda_8[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 9)            0           patch_model[0][0]
#                                                                  patch_model[1][0]
#                                                                  patch_model[2][0]
#                                                                  patch_model[3][0]
#                                                                  patch_model[4][0]
#                                                                  patch_model[5][0]
#                                                                  patch_model[6][0]
#                                                                  patch_model[7][0]
#                                                                  patch_model[8][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 1)            10          concatenate[0][0]
# ==================================================================================================
# Total params: 1,091,467
# Trainable params: 1,091,467
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import os
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras.losses import binary_crossentropy, MSE
import glob
import time
import random
import sys

class WGAN():
  def __init__(self, 
               img_size=128, 
               code_num = 2048,
               batch_size = 16, 
               train_epochs = 100, 
               train_steps = 8, 
               checkpoint_epochs = 25, 
               image_epochs = 1, 
               start_epoch = 1,
               optimizer = Adam(learning_rate = 1e-4),
               n_critics = 8
               ):
    
    self.batch_size = batch_size
    self.train_epochs =  train_epochs
    self.train_steps = train_steps
    self.checkpoint_epochs = checkpoint_epochs
    self.image_epochs = image_epochs
    self.start_epoch = start_epoch
    self.code_num = code_num
    self.img_size = img_size
    self.n_critics = n_critics
    
    self.gen_optimizer = optimizer
    self.disc_optimizer = optimizer

    g = Generator()
    self.gen = g.model()
    
    d = Discriminator()
    self.disc = d.model()

    checkpoint_dir = "drive/My Drive/PatchWGAN/checkpoint"
    checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
    checkpoint = tf.train.Checkpoint(gen_optimizer = self.gen_optimizer,
                                     disc_optimizer = self.disc_optimizer,
                                     gen = self.gen,
                                     disc = self.disc,
                                     )

    self.manager = tf.train.CheckpointManager(checkpoint, directory=checkpoint_dir, max_to_keep=2)

    train_image_path = 'drive/My Drive/samples/image'
    
    self.train_filenames = glob.glob(train_image_path + '/*.jpg') 

    checkpoint.restore(self.manager.latest_checkpoint)

    self.g_history = []
    self.d_history = []
    # self.endec_history = []  

  def preprocess_image(self, image):
    image = tf.image.decode_jpeg(image, channels=3)
    image = tf.image.resize(image, [self.img_size, self.img_size] )
    image = image/255  # normalize to [0,1] range
    return tf.cast(image, tf.float32)

  def load_and_preprocess_image(self, path):
    image = tf.io.read_file(path)
    return self.preprocess_image(image)

  def dataset(self, paths, batch_size):
    AUTOTUNE = tf.data.experimental.AUTOTUNE
    path_ds = tf.data.Dataset.from_tensor_slices(paths)
    img_ds = path_ds.map(self.load_and_preprocess_image, num_parallel_calls=AUTOTUNE)
    img_ds = img_ds.batch(batch_size)
    return img_ds

  def image_preparation(self, filenames, batch_size, steps):
    img_batch = []
    while 1:
      random.shuffle(filenames)
      for path in filenames:
        img_batch.append(path)
        if len(img_batch) == steps*batch_size:
          imgs = self.dataset(img_batch, batch_size)
          img_batch = []
          yield imgs

  def discriminator_loss(self, original_outputs, generated_outputs):
    real_loss = binary_crossentropy(tf.ones_like(original_outputs), original_outputs)
    generated_loss = binary_crossentropy(tf.zeros_like(generated_outputs), generated_outputs)
    loss_d = tf.math.reduce_mean(real_loss + generated_loss)
    return loss_d

  def generator_loss(self, generated_outputs):
    loss_g = tf.math.reduce_mean(binary_crossentropy(tf.ones_like(generated_outputs), generated_outputs))
    return loss_g

  def mse_loss(self, true, pred):
    loss =  tf.math.reduce_mean(MSE(true, pred))
    return loss

  def wasserstein_loss(self, ori_outputs, gen_outputs):
    d_loss = -tf.reduce_mean(ori_outputs) + tf.reduce_mean(gen_outputs)
    g_loss = -tf.reduce_mean(gen_outputs)
    return d_loss, g_loss
  
  def gan_train(self, imgs, n):
    noise =tf.random.uniform([self.batch_size, self.code_num], minval=0, maxval=1, dtype=tf.dtypes.float32)

    with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
      gen_imgs = self.gen(noise, training=True)

      ori_outputs = self.disc(imgs, training=True)
      gen_outputs = self.disc(gen_imgs, training=True)

      # ori_outputs, ori_styles = self.disc(imgs, training=True)
      # gen_outputs, gen_styles = self.disc(gen_imgs, training=True)
      
      # gen_loss = self.generator_loss(gen_outputs)      
      # disc_loss = self.discriminator_loss(ori_outputs, gen_outputs)

      # re_gen_imgs = self.gen(ori_styles, training=True)

      # endec_loss = self.mse_loss(imgs, re_gen_imgs)
      # self.endec_history.append(endec_loss)
      
      disc_loss, gen_loss = self.wasserstein_loss(ori_outputs, gen_outputs)
      self.g_history.append(gen_loss)
      self.d_history.append(disc_loss)

      # endec_rate = 10*(0.98**n)
      # g_loss = gen_loss + endec_loss * endec_rate
      # d_loss = disc_loss + endec_loss * endec_rate

      g_loss = gen_loss
      d_loss = disc_loss

    gradients_of_gen = gen_tape.gradient(g_loss, self.gen.trainable_variables)
    self.gen_optimizer.apply_gradients(zip(gradients_of_gen, self.gen.trainable_variables))

    gradients_of_disc = disc_tape.gradient(d_loss, self.disc.trainable_variables)    
    self.disc_optimizer.apply_gradients(zip(gradients_of_disc, self.disc.trainable_variables))

  def g_train(self, imgs):
    noise =tf.random.uniform([self.batch_size, self.code_num], minval=0, maxval=1, dtype=tf.dtypes.float32)

    with tf.GradientTape() as gen_tape:
      gen_imgs = self.gen(noise, training=True)

      ori_outputs = self.disc(imgs, training=False)
      gen_outputs = self.disc(gen_imgs, training=False)

      _, g_loss = self.wasserstein_loss(ori_outputs, gen_outputs)
      self.g_temp.append(g_loss)

    gradients_of_gen = gen_tape.gradient(g_loss, self.gen.trainable_variables)
    self.gen_optimizer.apply_gradients(zip(gradients_of_gen, self.gen.trainable_variables))

  def d_train(self, imgs):
    noise =tf.random.uniform([self.batch_size, self.code_num], minval=0, maxval=1, dtype=tf.dtypes.float32)

    with tf.GradientTape() as disc_tape:
      gen_imgs = self.gen(noise, training=False)

      ori_outputs = self.disc(imgs, training=True)
      gen_outputs = self.disc(gen_imgs, training=True)
      
      d_loss, _ = self.wasserstein_loss(ori_outputs, gen_outputs)
      self.d_temp.append(d_loss)

    gradients_of_disc = disc_tape.gradient(d_loss, self.disc.trainable_variables)    
    self.disc_optimizer.apply_gradients(zip(gradients_of_disc, self.disc.trainable_variables))

  def visualise_batch(self, s_1, epoch):
    gen_img = self.gen(s_1)  
    gen_img = (np.array(gen_img*255, np.uint8))
    fig, axes = plt.subplots(4, 6)
    for idx, img in enumerate(gen_img):
      p, q = idx//6, idx%6
      axes[p, q].imshow(img)
      axes[p, q].axis('off')
    
    save_name = 'drive/My Drive/PatchWGAN/generated_image/'+'image_at_epoch_{:04d}.png'
    plt.savefig(save_name.format(epoch), dpi=200)
    # plt.pause(0.1)
    plt.close('all')

  def loss_vis(self):
    plt.plot(self.g_history, 'b', self.d_history, 'r')
    plt.title('blue: g  red: d')
    plt.savefig('drive/My Drive/PatchWGAN/loss/gan_loss.png')
    plt.close('all')
    # plt.plot(self.endec_history)
    # plt.savefig('drive/My Drive/PatchWGAN/loss/endec_loss.png')
    # plt.close('all')

  def update_loss_history(self):
    self.d_history.append(sum(self.d_temp)/len(self.d_temp))
    self.g_history.append(sum(self.g_temp)/len(self.g_temp))
    self.d_temp = []
    self.g_temp = []

  def __call__(self):
    sample_noise =tf.random.uniform([24, self.code_num], minval=0, maxval=1, dtype=tf.dtypes.float32)
    image_loader = self.image_preparation(self.train_filenames, self.batch_size, self.train_steps)
    self.d_temp = []
    self.g_temp = []
    [w.assign(tf.clip_by_value(w, -0.01, 0.01)) for w in self.disc.variables]

    for epoch in range(self.start_epoch, self.train_epochs+1):
      print ('\nepochs {}'.format(epoch))
      imgs_ds = next(image_loader)

      for steps, imgs in enumerate(imgs_ds):
        print("\r" + 'steps{}'.format(steps+1), end="")
        sys.stdout.flush()

        self.d_train(imgs)
        [w.assign(tf.clip_by_value(w, -0.01, 0.01)) for w in self.disc.variables]

        if steps % self.n_critics == 0:
          self.g_train(imgs)
        
      self.update_loss_history()
                               
      if epoch % self.image_epochs == 0:
        self.visualise_batch(sample_noise, epoch)
        self.loss_vis()

      if epoch % self.checkpoint_epochs == 0:
        print ('\nSaving checkpoint at epoch{}\n\n'.format(epoch))
        self.manager.save()
      
if __name__ == '__main__':
  a = WGAN(img_size = 32,
           code_num = 8,
           batch_size = 256,
           train_epochs = 10000, 
           train_steps = 8, 
           checkpoint_epochs = 100, 
           image_epochs = 10, 
           start_epoch = 1,
           optimizer = RMSprop(lr=1E-5),
           n_critics = 1
           )
  a()
# Out:
# Streaming output truncated to the last 5000 lines.
# epochs 2039
# steps8
# epochs 2040
# steps8
# epochs 2041
# steps8
# epochs 2042
# steps8
# epochs 2043
# steps8
# epochs 2044
# steps8
# epochs 2045
# steps8
# epochs 2978
# steps8
# epochs 2979
# steps8
# epochs 2980
# steps8
# epochs 2981
# steps8
# epochs 2982
# steps8
# epochs 2983
# steps8
# epochs 2984
# steps8
# epochs 2985
# steps8
# epochs 2986
# steps8
# epochs 2987
# steps8
# epochs 2988
# steps8
# epochs 2989
# steps8
# epochs 2990
# steps8
# epochs 2991
# steps8
# epochs 2992
# steps8
# epochs 2993
# steps8
# epochs 2994
# steps8
# epochs 2995
# steps8
# epochs 2996
# steps8
# epochs 2997
# steps8
# epochs 2998
# steps8
# epochs 2999
# steps8
# epochs 3000
# steps8
# Saving checkpoint at epoch3000
#
#
#
# epochs 3001
# steps8
# epochs 3002
# steps8
# epochs 3003
# steps8
# epochs 3004
# steps8
# epochs 3005
# steps8
# epochs 3006
# steps8
# epochs 3007
# steps8
# epochs 3008
# steps8
# epochs 3009
# steps8
# epochs 3010
# steps8
# epochs 3011
# steps8
# epochs 3012
# steps8
# epochs 3013
# steps8
# epochs 3014
# steps8
# epochs 3015
# steps8
# epochs 3016
# steps8
# epochs 3017
# steps8
# epochs 3018
# steps8
# epochs 3019
# steps8
# epochs 3020
# steps8
# epochs 3021
# steps8
# epochs 3022
# steps8
# epochs 3023
# steps8
# epochs 3024
# steps8
# epochs 3025
# steps8
# epochs 3026
# steps8
# epochs 3027
# steps8
# epochs 3028
# steps8
# epochs 3029
# steps8
# epochs 3030
# steps8
# epochs 3031
# steps8
# epochs 3032
# steps8
# epochs 3033
# steps8
# epochs 3034
# steps8
# epochs 3035
# steps8
# epochs 3036
# steps8
# epochs 3037
# steps8
# epochs 3038
# steps8
# epochs 3039
# steps8
# epochs 3040
# steps8
# epochs 3041
# steps8
# epochs 3042
# steps8
# epochs 3043
# steps8
# epochs 3044
# steps8
# epochs 3045
# steps8
# epochs 3046
# steps8
# epochs 3047
# steps8
# epochs 3048
# steps8
# epochs 3049
# steps8
# epochs 3050
# steps8
# epochs 3051
# steps8
# epochs 3052
# steps8
# epochs 3053
# steps8
# epochs 3054
# steps8
# epochs 3055
# steps8
# epochs 3056
# steps8
# epochs 3057
# steps8
# epochs 3058
# steps8
# epochs 3059
# steps8
# epochs 3060
# steps8
# epochs 3061
# steps8
# epochs 3062
# steps8
# epochs 3063
# steps8
# epochs 3064
# steps8
# epochs 3065
# steps8
# epochs 3066
# steps8
# epochs 3067
# steps8
# epochs 3068
# steps8
# epochs 3069
# steps8
# epochs 3070
# steps8
# epochs 3071
# steps8
# epochs 3072
# steps8
# epochs 3073
# steps8
# epochs 3074
# steps8
# epochs 3075
# steps8
# epochs 3076
# steps8
# epochs 3077
# steps8
# epochs 3078
# steps8
# epochs 3079
# steps8
# epochs 3080
# steps8
# epochs 3081
# steps8
# epochs 3082
# steps8
# epochs 3083
# steps8
# epochs 3084
# steps8
# epochs 3085
# steps8
# epochs 3086
# steps8
# epochs 3087
# steps8
# epochs 3088
# steps8
# epochs 3089
# steps8
# epochs 3090
# steps8
# epochs 3091
# steps8
# epochs 3092
# steps8
# epochs 3093
# steps8
# epochs 3094
# steps8
# epochs 3095
# steps8
# epochs 3096
# steps8
# epochs 3097
# steps8
# epochs 3098
# steps8
# epochs 3099
# steps8
# epochs 3100
# steps8
# Saving checkpoint at epoch3100
#
#
#
# epochs 3101
# steps8
# epochs 3102
# steps8
# epochs 3103
# steps8
# epochs 3104
# steps8
# epochs 3105
# steps8
# epochs 3106
# steps8
# epochs 3107
# steps8
# epochs 3108
# steps8
# epochs 3109
# steps8
# epochs 3110
# steps8
# epochs 3111
# steps8
# epochs 3112
# steps8
# epochs 3113
# steps8
# epochs 3114
# steps8
# epochs 3115
# steps8
# epochs 3116
# steps8
# epochs 3117
# steps8
# epochs 3118
# steps8
# epochs 3119
# steps8
# epochs 3120
# steps8
# epochs 3121
# steps8
# epochs 3122
# steps8
# epochs 3123
# steps8
# epochs 3124
# steps8
# epochs 3125
# steps8
# epochs 3126
# steps8
# epochs 3127
# steps8
# epochs 3128
# steps8
# epochs 3129
# steps8
# epochs 3130
# steps8
# epochs 3131
# steps8
# epochs 3132
# steps8
# epochs 3133
# steps8
# epochs 3134
# steps8
# epochs 3135
# steps8
# epochs 3136
# steps8
# epochs 3137
# steps8
# epochs 3138
# steps8
# epochs 3139
# steps8
# epochs 3140
# steps8
# epochs 3141
# steps8
# epochs 3142
# steps8
# epochs 3143
# steps8
# epochs 3144
# steps8
# epochs 3145
# steps8
# epochs 3146
# steps8
# epochs 3147
# steps8
# epochs 3148
# steps8
# epochs 3149
# steps8
# epochs 3150
# steps8
# epochs 3151
# steps8
# epochs 3152
# steps8
# epochs 3153
# steps8
# epochs 3154
# steps8
# epochs 3155
# steps8
# epochs 3156
# steps8
# epochs 3157
# steps8
# epochs 3158
# steps8
# epochs 3159
# steps8
# epochs 3160
# steps8
# epochs 3161
# steps8
# epochs 3162
# steps8
# epochs 3163
# steps8
# epochs 3164
# steps8
# epochs 3165
# steps8
# epochs 3166
# steps8
# epochs 3167
# steps8
# epochs 3168
# steps8
# epochs 3169
# steps8
# epochs 3170
# steps8
# epochs 3171
# steps8
# epochs 3172
# steps8
# epochs 3173
# steps8
# epochs 3174
# steps8
# epochs 3175
# steps8
# epochs 3176
# steps8
# epochs 3177
# steps8
# epochs 3178
# steps8
# epochs 3179
# steps8
# epochs 3180
# steps8
# epochs 3181
# steps8
# epochs 3182
# steps8
# epochs 3183
# steps8
# epochs 3184
# steps8
# epochs 3185
# steps8
# epochs 3186
# steps8
# epochs 3187
# steps8
# epochs 3188
# steps8
# epochs 3189
# steps8
# epochs 3190
# steps8
# epochs 3191
# steps8
# epochs 3192
# steps8
# epochs 3193
# steps8
# epochs 3194
# steps8
# epochs 3195
# steps8
# epochs 3196
# steps8
# epochs 3197
# steps8
# epochs 3198
# steps8
# epochs 3199
# steps8
# epochs 3200
# steps8
# Saving checkpoint at epoch3200
#
#
#
# epochs 3201
# steps8
# epochs 3202
# steps8
# epochs 3203
# steps8
# epochs 3204
# steps8
# epochs 3205
# steps8
# epochs 3206
# steps8
# epochs 3207
# steps8
# epochs 3208
# steps8
# epochs 3209
# steps8
# epochs 3210
# steps8
# epochs 3211
# steps8
# epochs 3212
# steps8
# epochs 3213
# steps8
# epochs 3214
# steps8
# epochs 3215
# steps8
# epochs 3216
# steps8
# epochs 3217
# steps8
# epochs 3218
# steps8
# epochs 3219
# steps8
# epochs 3220
# steps8
# epochs 3221
# steps8
# epochs 3222
# steps8
# epochs 3223
# steps8
# epochs 3224
# steps8
# epochs 3225
# steps8
# epochs 3226
# steps8
# epochs 3227
# steps8
# epochs 3228
# steps8
# epochs 3229
# steps8
# epochs 3230
# steps8
# epochs 3231
# steps8
# epochs 3232
# steps8
# epochs 3233
# steps8
# epochs 3234
# steps8
# epochs 3235
# steps8
# epochs 3236
# steps8
# epochs 3237
# steps8
# epochs 3238
# steps8
# epochs 3239
# steps8
# epochs 3240
# steps8
# epochs 3241
# steps8
# epochs 3242
# steps8
# epochs 3243
# steps8
# epochs 3244
# steps8
# epochs 3245
# steps8
# epochs 3246
# steps8
# epochs 3247
# steps8
# epochs 3248
# steps8
# epochs 3249
# steps8
# epochs 3250
# steps8
# epochs 3251
# steps8
# epochs 3252
# steps8
# epochs 3253
# steps8
# epochs 3254
# steps8
# epochs 3255
# steps8
# epochs 3256
# steps8
# epochs 3257
# steps8
# epochs 3258
# steps8
# epochs 3259
# steps8
# epochs 3260
# steps8
# epochs 3261
# steps8
# epochs 3262
# steps8
# epochs 3263
# steps8
# epochs 3264
# steps8
# epochs 3265
# steps8
# epochs 3266
# steps8
# epochs 3267
# steps8
# epochs 3268
# steps8
# epochs 3269
# steps8
# epochs 3270
# steps8
# epochs 3271
# steps8
# epochs 3272
# steps8
# epochs 3273
# steps8
# epochs 3274
# steps8
# epochs 3275
# steps8
# epochs 3276
# steps8
# epochs 3277
# steps8
# epochs 3278
# steps8
# epochs 3279
# steps8
# epochs 3280
# steps8
# epochs 3281
# steps8
# epochs 3282
# steps8
# epochs 3283
# steps8
# epochs 3284
# steps8
# epochs 3285
# steps8
# epochs 3286
# steps8
# epochs 3287
# steps8
# epochs 3288
# steps8
# epochs 3289
# steps8
# epochs 3290
# steps8
# epochs 3291
# steps8
# epochs 3292
# steps8
# epochs 3293
# steps8
# epochs 3294
# steps8
# epochs 3295
# steps8
# epochs 3296
# steps8
# epochs 3297
# steps8
# epochs 3298
# steps8
# epochs 3299
# steps8
# epochs 3300
# steps8
# Saving checkpoint at epoch3300
#
#
#
# epochs 3301
# steps8
# epochs 3302
# steps8
# epochs 3303
# steps8
# epochs 3304
# steps8
# epochs 3305
# steps8
# epochs 3306
# steps8
# epochs 3307
# steps8
# epochs 3308
# steps8
# epochs 3309
# steps8
# epochs 3310
# steps8
# epochs 3311
# steps8
# epochs 3312
# steps8
# epochs 3313
# steps8
# epochs 3314
# steps8
# epochs 3315
# steps8
# epochs 3316
# steps8
# epochs 3317
# steps8
# epochs 3318
# steps8
# epochs 3319
# steps8
# epochs 3320
# steps8
# epochs 3321
# steps8
# epochs 3322
# steps8
# epochs 3323
# steps8
# epochs 3324
# steps8
# epochs 3325
# steps8
# epochs 3326
# steps8
# epochs 3327
# steps8
# epochs 3328
# steps8
# epochs 3329
# steps8
# epochs 3330
# steps8
# epochs 3331
# steps8
# epochs 3332
# steps8
# epochs 3333
# steps8
# epochs 3334
# steps8
# epochs 3335
# steps8
# epochs 3336
# steps8
# epochs 3337
# steps8
# epochs 3338
# steps8
# epochs 3339
# steps8
# epochs 3340
# steps8
# epochs 3341
# steps8
# epochs 3342
# steps8
# epochs 3343
# steps8
# epochs 3344
# steps8
# epochs 3345
# steps8
# epochs 3346
# steps8
# epochs 3347
# steps8
# epochs 3348
# steps8
# epochs 3349
# steps8
# epochs 3350
# steps8
# epochs 3351
# steps8
# epochs 3352
# steps8
# epochs 3353
# steps8
# epochs 3354
# steps8
# epochs 3355
# steps8
# epochs 3356
# steps8
# epochs 3357
# steps8
# epochs 3358
# steps8
# epochs 3359
# steps8
# epochs 3360
# steps8
# epochs 3361
# steps8
# epochs 3362
# steps8
# epochs 3363
# steps8
# epochs 3364
# steps8
# epochs 3365
# steps8
# epochs 3366
# steps8
# epochs 3367
# steps8
# epochs 3368
# steps8
# epochs 3369
# steps8
# epochs 3370
# steps8
# epochs 3371
# steps8
# epochs 3372
# steps8
# epochs 3373
# steps8
# epochs 3374
# steps8
# epochs 3375
# steps8
# epochs 3376
# steps8
# epochs 3377
# steps8
# epochs 3378
# steps8
# epochs 3379
# steps8
# epochs 3380
# steps8
# epochs 3381
# steps8
# epochs 3382
# steps8
# epochs 3383
# steps8
# epochs 3384
# steps8
# epochs 3385
# steps8
# epochs 3386
# steps8
# epochs 3387
# steps8
# epochs 3388
# steps8
# epochs 3389
# steps8
# epochs 3390
# steps8
# epochs 3391
# steps8
# epochs 3392
# steps8
# epochs 3393
# steps8
# epochs 3394
# steps8
# epochs 3395
# steps8
# epochs 3396
# steps8
# epochs 3397
# steps8
# epochs 3398
# steps8
# epochs 3399
# steps8
# epochs 3400
# steps8
# Saving checkpoint at epoch3400
#
#
#
# epochs 3401
# steps8
# epochs 3402
# steps8
# epochs 3403
# steps8
# epochs 3404
# steps8
# epochs 3405
# steps8
# epochs 3406
# steps8
# epochs 3407
# steps8
# epochs 3408
# steps8
# epochs 3409
# steps8
# epochs 3410
# steps8
# epochs 3411
# steps8
# epochs 3412
# steps8
# epochs 3413
# steps8
# epochs 3414
# steps8
# epochs 3415
# steps8
# epochs 3416
# steps8
# epochs 3417
# steps8
# epochs 3418
# steps8
# epochs 3419
# steps8
# epochs 3420
# steps8
# epochs 3421
# steps8
# epochs 3422
# steps8
# epochs 3423
# steps8
# epochs 3424
# steps8
# epochs 3425
# steps8
# epochs 3426
# steps8
# epochs 3427
# steps8
# epochs 3428
# steps8
# epochs 3429
# steps8
# epochs 3430
# steps8
# epochs 3431
# steps8
# epochs 3432
# steps8
# epochs 3433
# steps8
# epochs 3434
# steps8
# epochs 3435
# steps8
# epochs 3436
# steps8
# epochs 3437
# steps8
# epochs 3438
# steps8
# epochs 3439
# steps8
# epochs 3440
# steps8
# epochs 3441
# steps8
# epochs 3442
# epochs 3559
# steps8
# epochs 3560
# steps8
# epochs 3561
# steps8
# epochs 3562
# steps8
# epochs 3563
# steps8
# epochs 3564
# steps8
# epochs 3565
# steps8
# epochs 3566
# steps8
# epochs 3567
# steps8
# epochs 3568
# steps8
# epochs 3569
# steps8
# epochs 3570
# steps8
# epochs 3571
# steps8
# epochs 3572
# steps8
# epochs 3573
# steps8
# epochs 3574
# steps8
# epochs 3575
# steps8
# epochs 3576
# steps8
# epochs 3577
# steps8
# epochs 3578
# steps8
# epochs 3579
# steps8
# epochs 3580
# steps8
# epochs 3581
# steps8
# epochs 3582
# steps8
# epochs 3583
# steps8
# epochs 3584
# steps8
# epochs 3585
# steps8
# epochs 3586
# steps8
# epochs 3587
# steps8
# epochs 3588
# steps8
# epochs 3589
# steps8
# epochs 3590
# steps8
# epochs 3591
# steps8
# epochs 3592
# steps8
# epochs 3593
# steps8
# epochs 3594
# steps8
# epochs 3595
# steps8
# epochs 3596
# steps8
# epochs 3597
# steps8
# epochs 3598
# steps8
# epochs 3599
# steps8
# epochs 3600
# steps8
# Saving checkpoint at epoch3600
#
#
#
# epochs 3601
# steps8
# epochs 3602
# steps8
# epochs 3603
# steps8
# epochs 3604
# steps8
# epochs 3605
# steps8
# epochs 3606
# steps8
# epochs 3607
# steps8
# epochs 3608
# steps8
# epochs 3609
# steps8
# epochs 3610
# steps8
# epochs 3611
# steps8
# epochs 3612
# steps8
# epochs 3613
# steps8
# epochs 3614
# steps8
# epochs 3615
# steps8
# epochs 3616
# steps8
# epochs 3617
# steps8
# epochs 3618
# steps8
# epochs 3619
# steps8
# epochs 3620
# steps8
# epochs 3621
# steps8
# epochs 3622
# steps8
# epochs 3623
# steps8
# epochs 3624
# steps8
# epochs 3625
# steps8
# epochs 3626
# steps8
# epochs 3627
# steps8
# epochs 3628
# steps8
# epochs 3629
# steps8
# epochs 3630
# steps8
# epochs 3631
# steps8
# epochs 3632
# steps8
# epochs 3633
# steps8
# epochs 3634
# steps8
# epochs 3635
# steps8
# epochs 3636
# steps8
# epochs 3637
# steps8
# epochs 3638
# steps8
# epochs 3639
# steps8
# epochs 3640
# steps8
# epochs 3641
# steps8
# epochs 3642
# steps8
# epochs 3643
# steps8
# epochs 3644
# steps8
# epochs 3645
# steps8
# epochs 3646
# steps8
# epochs 3647
# steps8
# epochs 3648
# steps8
# epochs 3649
# steps8
# epochs 3650
# steps8
# epochs 3651
# steps8
# epochs 3652
# steps8
# epochs 3653
# steps8
# epochs 3654
# steps8
# epochs 3655
# steps8
# epochs 3656
# steps8
# epochs 3657
# steps8
# epochs 3658
# steps8
# epochs 3659
# steps8
# epochs 3660
# steps8
# epochs 3661
# steps8
# epochs 3662
# steps8
# epochs 3663
# steps8
# epochs 3664
# steps8
# epochs 3665
# steps8
# epochs 3666
# steps8
# epochs 3667
# steps8
# epochs 3668
# steps8
# epochs 3669
# steps8
# epochs 3670
# steps8
# epochs 3671
# steps8
# epochs 3672
# steps8
# epochs 3673
# steps8
# epochs 3674
# steps8
# epochs 3675
# steps8
# steps8
# epochs 3793
# steps8
# epochs 3794
# steps8
# epochs 3795
# steps8
# epochs 3796
# steps8
# epochs 3797
# steps8
# epochs 3798
# steps8
# epochs 3799
# steps8
# epochs 3800
# steps8
# Saving checkpoint at epoch3800
#
#
#
# epochs 3801
# steps8
# epochs 3802
# steps8
# epochs 3803
# steps8
# epochs 3804
# steps8
# epochs 3805
# steps8
# epochs 3806
# steps8
# epochs 3807
# steps8
# epochs 3808
# steps8
# epochs 3809
# steps8
# epochs 3810
# steps8
# epochs 3811
# steps8
# epochs 3812
# steps8
# epochs 3813
# steps8
# epochs 3814
# steps8
# epochs 3815
# steps8
# epochs 3816
# steps8
# epochs 3817
# steps8
# epochs 3818
# steps8
# epochs 3819
# steps8
# epochs 3820
# steps8
# epochs 3821
# steps8
# epochs 3822
# steps8
# epochs 3823
# steps8
# epochs 3824
# steps8
# epochs 3825
# steps8
# epochs 3826
# steps8
# epochs 3827
# steps8
# epochs 3828
# steps8
# epochs 3829
# steps8
# epochs 3830
# steps8
# epochs 3831
# steps8
# epochs 3832
# steps8
# epochs 3833
# steps8
# epochs 3834
# steps8
# epochs 3835
# steps8
# epochs 3836
# steps8
# epochs 3837
# steps8
# epochs 3838
# steps8
# epochs 3839
# steps8
# epochs 3840
# steps8
# epochs 3841
# steps8
# epochs 3842
# steps8
# epochs 3843
# steps8
# epochs 3844
# steps8
# epochs 3845
# steps8
# epochs 3846
# steps8
# epochs 3847
# steps8
# epochs 3848
# steps8
# epochs 3849
# steps8
# epochs 3850
# steps8
# epochs 3851
# steps8
# epochs 3852
# steps8
# epochs 3853
# steps8
# epochs 3854
# steps8
# epochs 3855
# steps8
# epochs 3856
# steps8
# epochs 3857
# steps8
# epochs 3858
# steps8
# epochs 3859
# steps8
# epochs 3860
# steps8
# epochs 3861
# steps8
# epochs 3862
# steps8
# epochs 3863
# steps8
# epochs 3864
# steps8
# epochs 3865
# steps8
# epochs 3866
# steps8
# epochs 3867
# steps8
# epochs 3868
# steps8
# epochs 3869
# steps8
# epochs 3870
# steps8
# epochs 3871
# steps8
# epochs 3872
# steps8
# epochs 3873
# steps8
# epochs 3874
# steps8
# epochs 3875
# steps8
# epochs 3876
# steps8
# epochs 3877
# steps8
# epochs 3878
# steps8
# epochs 3879
# steps8
# epochs 3880
# steps8
# epochs 3881
# steps8
# epochs 3882
# steps8
# epochs 3883
# steps8
# epochs 3884
# steps8
# epochs 3885
# steps8
# epochs 3886
# steps8
# epochs 3887
# steps8
# epochs 3888
# steps8
# epochs 3889
# steps8
# epochs 3890
# steps8
# epochs 3891
# steps8
# epochs 3892
# steps8
# epochs 3893
# steps8
# epochs 3894
# steps8
# epochs 3895
# steps8
# epochs 3896
# steps8
# epochs 3897
# steps8
# epochs 3898
# steps8
# epochs 3899
# steps8
# epochs 3900
# steps8
# Saving checkpoint at epoch3900
#
#
#
# epochs 3901
# steps8
# epochs 3902
# steps8
# epochs 3903
# steps8
# epochs 3904
# steps8
# epochs 3905
# steps8
# epochs 3906
# steps8
# epochs 3907
# steps8
# epochs 3908
# steps8
# epochs 3909
# steps8
# epochs 3910
# steps8
# epochs 3911
# steps8
# epochs 3912
# steps8
# epochs 3913
# steps8
# epochs 3914
# steps8
# epochs 3915
# steps8
# epochs 3916
# steps8
# epochs 3917
# steps8
# epochs 3918
# steps8
# epochs 3919
# steps8
# epochs 3920
# steps8
# epochs 3921
# steps8
# epochs 3922
# steps8
# epochs 3923
# steps8
# epochs 3924
# steps8
# epochs 3925
# steps8
# epochs 3926
# steps8
# epochs 3927
# steps8
# epochs 3928
# steps8
# epochs 3929
# steps8
# epochs 3930
# steps8
# epochs 3931
# steps8
# epochs 3932
# steps8
# epochs 3933
# steps8
# epochs 3934
# steps8
# epochs 3935
# steps8
# epochs 3936
# steps8
# epochs 3937
# steps8
# epochs 3938
# steps8
# epochs 3939
# steps8
# epochs 3940
# steps8
# epochs 3941
# steps8
# epochs 3942
# steps8
# epochs 3943
# steps8
# epochs 3944
# steps8
# epochs 3945
# steps8
# epochs 3946
# steps8
# epochs 3947
# steps8
# epochs 3948
# steps8
# epochs 3949
# steps8
# epochs 3950
# steps8
# epochs 3951
# steps8
# epochs 3952
# steps8
# epochs 3953
# steps8
# epochs 3954
# steps8
# epochs 3955
# steps8
# epochs 3956
# steps8
# epochs 3957
# steps8
# epochs 3958
# steps8
# epochs 3959
# steps8
# epochs 3960
# steps8
# epochs 3961
# steps8
# epochs 3962
# steps8
# epochs 3963
# steps8
# epochs 3964
# steps8
# epochs 3965
# steps8
# epochs 3966
# steps8
# epochs 3967
# steps8
# epochs 3968
# steps8
# epochs 3969
# steps8
# epochs 3970
# steps8
# epochs 3971
# steps8
# epochs 3972
# steps8
# epochs 3973
# steps8
# epochs 3974
# steps8
# epochs 3975
# steps8
# epochs 3976
# steps8
# epochs 3977
# steps8
# epochs 3978
# steps8
# epochs 3979
# steps8
# epochs 3980
# steps8
# epochs 3981
# steps8
# epochs 3982
# steps8
# epochs 3983
# steps8
# epochs 3984
# steps8
# epochs 3985
# steps8
# epochs 3986
# steps8
# epochs 3987
# steps8
# epochs 3988
# steps8
# epochs 3989
# steps8
# epochs 3990
# steps8
# epochs 3991
# steps8
# epochs 3992
# steps8
# epochs 3993
# steps8
# epochs 3994
# steps8
# epochs 3995
# steps8
# epochs 3996
# steps8
# epochs 3997
# steps8
# epochs 3998
# steps8
# epochs 3999
# steps8
# epochs 4000
# steps8
# Saving checkpoint at epoch4000
#
#
#
# epochs 4001
# steps8
# epochs 4002
# steps8
# epochs 4003
# steps8
# epochs 4004
# steps8
# epochs 4005
# steps8
# epochs 4006
# steps8
# epochs 4007
# steps8
# epochs 4008
# steps8
# epochs 4009
# steps8
# epochs 4010
# steps8
# epochs 4011
# steps8
# epochs 4012
# steps8
# epochs 4013
# steps8
# epochs 4014
# steps8
# epochs 4015
# steps8
# epochs 4016
# steps8
# epochs 4017
# steps8
# epochs 4018
# steps8
# epochs 4019
# steps8
# epochs 4020
# steps8
# epochs 4021
# steps8
# epochs 4022
# steps8
# epochs 4023
# steps8
# epochs 4024
# steps8
# epochs 4025
# steps8
# epochs 4026
# steps8
# epochs 4027
# steps8
# epochs 4028
# steps8
# epochs 4029
# steps8
# epochs 4030
# steps8
# epochs 4031
# steps8
# epochs 4032
# steps8
# epochs 4033
# steps8
# epochs 4034
# steps8
# epochs 4035
# steps8
# epochs 4036
# steps8
# epochs 4037
# steps8
# epochs 4038
# steps8
# epochs 4039
# steps8
# epochs 4040
# steps8
# epochs 4041
# steps8
# epochs 4042
# steps8
# epochs 4043
# steps8
# epochs 4044
# steps8
# epochs 4045
# steps8
# epochs 4046
# steps8
# epochs 4047
# steps8
# epochs 4048
# steps8
# epochs 4049
# steps8
# epochs 4050
# steps8
# epochs 4051
# steps8
# epochs 4052
# steps8
# epochs 4053
# steps8
# epochs 4054
# steps8
# epochs 4055
# steps8
# epochs 4056
# steps8
# epochs 4057
# steps8
# epochs 4058
# steps8
# epochs 4059
# steps8
# epochs 4060
# steps8
# epochs 4061
# steps8
# epochs 4062
# steps8
# epochs 4063
# steps8
# epochs 4064
# steps8
# epochs 4065
# steps8
# epochs 4066
# steps8
# epochs 4067
# steps8
# epochs 4068
# steps8
# epochs 4069
# steps8
# epochs 4070
# steps8
# epochs 4071
# steps8
# epochs 4072
# steps8
# epochs 4073
# steps8
# epochs 4074
# steps8
# epochs 4075
# steps8
# epochs 4076
# steps8
# epochs 4077
# steps8
# epochs 4078
# steps8
# epochs 4079
# steps8
# epochs 4080
# steps8
# epochs 4081
# steps8
# epochs 4082
# steps8
# epochs 4083
# steps8
# epochs 4084
# steps8
# epochs 4085
# steps8
# epochs 4086
# steps8
# epochs 4087
# steps8
# epochs 4088
# steps8
# epochs 4089
# steps8
# epochs 4090
# steps8
# epochs 4091
# steps8
# epochs 4092
# steps8
# epochs 4093
# steps8
# epochs 4094
# steps8
# epochs 4095
# steps8
# epochs 4096
# steps8
# epochs 4097
# steps8
# epochs 4098
# steps8
# epochs 4099
# steps8
# epochs 4100
# steps8
# Saving checkpoint at epoch4100
#
#
#
# epochs 4101
# steps8
# epochs 4102
# steps8
# epochs 4103
# steps8
# epochs 4104
# steps8
# epochs 4105
# steps8
# epochs 4106
# steps8
# epochs 4107
# steps8
# epochs 4108
# steps8
# epochs 4109
# steps8
# epochs 4110
# steps8
# epochs 4111
# steps8
# epochs 4112
# steps8
# epochs 4113
# steps8
# epochs 4114
# steps8
# epochs 4115
# steps8
# epochs 4116
# steps8
# epochs 4117
# steps8
# epochs 4118
# steps8
# epochs 4119
# steps8
# epochs 4120
# steps8
# epochs 4121
# steps8
# epochs 4122
# steps8
# epochs 4123
# steps8
# epochs 4124
# steps8
# epochs 4125
# steps8
# epochs 4126
# steps8
# epochs 4127
# steps8
# epochs 4128
# steps8
# epochs 4129
# steps8
# epochs 4130
# steps8
# epochs 4131
# steps8
# epochs 4132
# steps8
# epochs 4133
# steps8
# epochs 4134
# steps8
# epochs 4135
# steps8
# epochs 4136
# steps8
# epochs 4137
# steps8
# epochs 4138
# steps8
# epochs 4139
# steps8
# epochs 4140
# steps8
# epochs 4141
# steps8
# epochs 4142
# steps8
# epochs 4143
# steps8
# epochs 4144
# steps8
# epochs 4145
# steps8
# epochs 4146
# steps8
# epochs 4147
# steps8
# epochs 4148
# steps8
# epochs 4149
# steps8
# epochs 4150
# steps8
# epochs 4151
# steps8
# epochs 4152
# steps8
# epochs 4153
# steps8
# epochs 4154
# steps8
# epochs 4155
# steps8
# epochs 4156
# steps8
# epochs 4157
# steps8
# epochs 4158
# steps8
# epochs 4159
# steps8
# epochs 4160
# steps8
# epochs 4161
# steps8
# epochs 4162
# steps8
# epochs 4163
# steps8
# epochs 4164
# steps8
# epochs 4165
# steps8
# epochs 4166
# steps8
# epochs 4167
# steps8
# epochs 4168
# steps8
# epochs 4169
# steps8
# epochs 4170
# steps8
# epochs 4171
# steps8
# epochs 4172
# steps8
# epochs 4173
# steps8
# epochs 4174
# steps8
# epochs 4175
# steps8
# epochs 4176
# steps8
# epochs 4177
# steps8
# epochs 4178
# steps8
# epochs 4179
# steps8
# epochs 4180
# steps8
# epochs 4181
# steps8
# epochs 4182
# steps8
# epochs 4183
# steps8
# epochs 4184
# steps8
# epochs 4185
# steps8
# epochs 4186
# steps8
# epochs 4187
# steps8
# epochs 4188
# steps8
# epochs 4189
# steps8
# epochs 4190
# steps8
# epochs 4191
# steps8
# epochs 4192
# steps8
# epochs 4193
# steps8
# epochs 4194
# steps8
# epochs 4195
# steps8
# epochs 4196
# steps8
# epochs 4197
# steps8
# epochs 4198
# steps8
# epochs 4199
# steps8
# epochs 4200
# steps8
# Saving checkpoint at epoch4200
#
#
#
# epochs 4201
# steps8
# epochs 4202
# steps8
# epochs 4203
# steps8
# epochs 4204
# steps8
# epochs 4205
# steps8
# epochs 4206
# steps8
# epochs 4207
# steps8
# epochs 4208
# steps8
# epochs 4209
# steps8
# epochs 4210
# steps8
# epochs 4211
# steps8
# epochs 4212
# steps8
# epochs 4213
# steps8
# epochs 4214
# steps8
# epochs 4215
# steps8
# epochs 4216
# steps8
# epochs 4217
# steps8
# epochs 4218
# steps8
# epochs 4219
# steps8
# epochs 4220
# steps8
# epochs 4221
# steps8
# epochs 4222
# steps8
# epochs 4223
# steps8
# epochs 4224
# steps8
# epochs 4225
# steps8
# epochs 4226
# steps8
# epochs 4227
# steps8
# epochs 4228
# steps8
# epochs 4229
# steps8
# epochs 4230
# steps8
# epochs 4231
# steps8
# epochs 4232
# steps8
# epochs 4233
# steps8
# epochs 4234
# steps8
# epochs 4235
# steps8
# epochs 4236
# steps8
# epochs 4237
# steps8
# epochs 4238
# steps8
# epochs 4239
# steps8
# epochs 4240
# steps8
# epochs 4241
# steps8
# epochs 4242
# steps8
# epochs 4243
# steps8
# epochs 4244
# steps8
# epochs 4245
# steps8
# epochs 4246
# steps8
# epochs 4247
# steps8
# epochs 4248
# steps8
# epochs 4249
# steps8
# epochs 4250
# steps8
# epochs 4251
# steps8
# epochs 4252
# steps8
# epochs 4253
# steps8
# epochs 4254
# steps8
# epochs 4255
# steps8
# epochs 4256
# steps8
# epochs 4257
# steps8
# epochs 4258
# steps8
# epochs 4259
# steps8
# epochs 4260
# steps8
# epochs 4261
# steps8
# epochs 4262
# steps8
# epochs 4263
# steps8
# epochs 4264
# steps8
# epochs 4265
# steps8
# epochs 4266
# steps8
# epochs 4267
# steps8
# epochs 4268
# steps8
# epochs 4269
# steps8
# epochs 4270
# steps8
# epochs 4271
# steps8
# epochs 4272
# steps8
# epochs 4273
# steps8
# epochs 4274
# steps8
# epochs 4275
# steps8
# epochs 4276
# steps8
# epochs 4277
# steps8
# epochs 4278
# steps8
# epochs 4279
# steps8
# epochs 4280
# steps8
# epochs 4281
# steps8
# epochs 4282
# steps8
# epochs 4283
# steps8
# epochs 4284
# steps8
# epochs 4285
# steps8
# epochs 4286
# steps8
# epochs 4287
# steps8
# epochs 4288
# steps8
# epochs 4289
# steps8
# epochs 4290
# steps8
# epochs 4291
# steps8
# epochs 4292
# steps8
# epochs 4293
# steps8
# epochs 4294
# steps8
# epochs 4295
# steps8
# epochs 4296
# steps8
# epochs 4297
# steps8
# epochs 4298
# steps8
# epochs 4299
# steps8
# epochs 4300
# steps8
# Saving checkpoint at epoch4300
#
#
#
# epochs 4301
# steps8
# epochs 4302
# steps8
# epochs 4303
# steps8
# epochs 4304
# steps8
# epochs 4305
# steps8
# epochs 4306
# steps8
# epochs 4307
# steps8
# epochs 4308
# steps8
# epochs 4309
# steps8
# epochs 4310
# steps8
# epochs 4311
# steps8
# epochs 4312
# steps8
# epochs 4313
# steps8
# epochs 4314
# steps8
# epochs 4315
# steps8
# epochs 4316
# steps8
# epochs 4317
# steps8
# epochs 4318
# steps8
# epochs 4319
# steps8
# epochs 4320
# steps8
# epochs 4321
# steps8
# epochs 4322
# steps8
# epochs 4323
# steps8
# epochs 4324
# steps8
# epochs 4325
# steps8
# epochs 4326
# steps8
# epochs 4327
# steps8
# epochs 4328
# steps8
# epochs 4329
# steps8
# epochs 4330
# steps8
# epochs 4331
# steps8
# epochs 4332
# steps8
# epochs 4333
# steps8
# epochs 4334
# steps8
# epochs 4335
# steps8
# epochs 4336
# steps8
# epochs 4337
# steps8
# epochs 4338
# steps8
# epochs 4339
# steps8
# epochs 4340
# steps8
# epochs 4341
# steps8
# epochs 4342
# steps8
# epochs 4343
# steps8
# epochs 4344
# steps8
# epochs 4345
# steps8
# epochs 4346
# steps8
# epochs 4347
# steps8
# epochs 4348
# steps8
# epochs 4349
# steps8
# epochs 4350
# steps8
# epochs 4351
# steps8
# epochs 4352
# steps8
# epochs 4353
# steps8
# epochs 4354
# steps8
# epochs 4355
# steps8
# epochs 4356
# steps8
# epochs 4357
# steps8
# epochs 4358
# steps8
# epochs 4359
# steps8
# epochs 4360
# steps8
# epochs 4361
# steps8
# epochs 4362
# steps8
# epochs 4363
# steps8
# epochs 4364
# steps8
# epochs 4365
# steps8
# epochs 4366
# steps8
# epochs 4367
# steps8
# epochs 4368
# steps8
# epochs 4369
# steps8
# epochs 4370
# steps8
# epochs 4371
# steps8
# epochs 4372
# steps8
# epochs 4373
# steps8
# epochs 4374
# steps8
# epochs 4375
# steps8
# epochs 4376
# steps8
# epochs 4377
# steps8
# epochs 4378
# steps8
# epochs 4379
# steps8
# epochs 4380
# steps8
# epochs 4381
# steps8
# epochs 4382
# steps8
# epochs 4383
# steps8
# epochs 4384
# steps8
# epochs 4385
# steps8
# epochs 4386
# steps8
# epochs 4387
# steps8
# epochs 4388
# steps8
# epochs 4389
# steps8
# epochs 4390
# steps8
# epochs 4391
# steps8
# epochs 4392
# steps8
# epochs 4393
# steps8
# epochs 4394
# steps8
# epochs 4395
# steps8
# epochs 4396
# steps8
# epochs 4397
# steps8
# epochs 4398
# steps8
# epochs 4399
# steps8
# epochs 4400
# steps8
# Saving checkpoint at epoch4400
#
#
#
# epochs 4401
# steps8
# epochs 4402
# steps8
# epochs 4403
# steps8
# epochs 4404
# steps8
# epochs 4405
# steps8
# epochs 4406
# steps8
# epochs 4407
# steps8
# epochs 4408
# steps8
# epochs 4409
# steps8
# epochs 4410
# steps8
# epochs 4411
# steps8
# epochs 4412
# steps8
# epochs 4413
# steps8
# epochs 4414
# steps8
# epochs 4415
# steps8
# epochs 4416
# steps8
# epochs 4417
# steps8
# epochs 4418
# steps8
# epochs 4419
# steps8
# epochs 4420
# steps8
# epochs 4421
# steps8
# epochs 4422
# steps8
# epochs 4423
# steps8
# epochs 4424
# steps8
# epochs 4425
# steps8
# epochs 4426
# steps8
# epochs 4427
# steps8
# epochs 4428
# steps8
# epochs 4429
# steps8
# epochs 4430
# steps8
# epochs 4431
# steps8
# epochs 4432
# steps8
# epochs 4433
# steps8
# epochs 4434
# steps8
# epochs 4435
# steps8
# epochs 4436
# steps8
# epochs 4437
# steps8
# epochs 4438
# steps8
# epochs 4439
# steps8
# epochs 4440
# steps8
# epochs 4441
# steps8
# epochs 4442
# steps8
# epochs 4443
# steps8
# epochs 4444
# steps8
# epochs 4445
# steps8
# epochs 4446
# steps8
# epochs 4447
# steps8
# epochs 4448
# steps8
# epochs 4449
# steps8
# epochs 4450
# steps8
# epochs 4451
# steps8
# epochs 4452
# steps8
# epochs 4453
# steps8
# epochs 4454
# steps8
# epochs 4455
# steps8
# epochs 4456
# steps8
# epochs 4457
# steps8
# epochs 4458
# steps8
# epochs 4459
# steps8
# epochs 4460
# steps8
# epochs 4461
# steps8
# epochs 4462
# steps8
# epochs 4463
# steps8
# epochs 4464
# steps8
# epochs 4465
# steps8
# epochs 4466
# steps8
# epochs 4467
# steps8
# epochs 4468
# steps8
# epochs 4469
# steps8
# epochs 4470
# steps8
# epochs 4471
# steps8
# epochs 4472
# steps8
# epochs 4473
# steps8
# epochs 4474
# steps8
# epochs 4475
# steps8
# epochs 4476
# steps8
# epochs 4477
# steps8
# epochs 4478
# steps8
# epochs 4479
# steps8
# epochs 4480
# steps8
# epochs 4481
# steps8
# epochs 4482
# steps8
# epochs 4483
# steps8
# epochs 4484
# steps8
# epochs 4485
# steps8
# epochs 4486
# steps8
# epochs 4487
# steps8
# epochs 4488
# steps8
# epochs 4489
# steps8
# epochs 4490
# steps7
